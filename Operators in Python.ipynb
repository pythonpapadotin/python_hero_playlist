# %% [markdown]
# ![Python Operators](media/python_operators.png)

# %%
x = 4 + 5

# %%
x
# Out:
# 9

# %%
x = 6-5

# %%
x
# Out:
# 1

# %%
x = 6*2

# %%
x
# Out:
# 12

# %%
x = 5/3
print(x)
# Out:
# 1.6666666666666667

# %%
# Modulus operator %

x = 5%3
print(x)
# Out:
# 2

# %%
x = 7%4
print(x)
# Out:
# 3

# %%
# **

2**4
# Out:
# 16

# %%
# //

# rounds down the result. (towards - inf)

result = 7/4

print(result)
# Out:
# 1.75

# %%
result = 7//4

print(result)
# Out:
# 1

# %%
result = -7//4

# %%
print(result)
# Out:
# -2

# %%
x = ['kiwi', 'apple'] + ['banana', 'mango']

# %%
print(x)
# Out:
# ['kiwi', 'apple', 'banana', 'mango']

# %%
x = {'python': 4} + ['apple']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-6add65889e97> in <module>
# ----> 1 x = {'python': 4} + ['apple']
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'list'

# %%
7 > 4
# Out:
# True

# %%
8 == 4
# Out:
# False

# %%
7 < 4
# Out:
# False

# %%
8 != 4
# Out:
# True

# %%
x = 78

# %%
x *= 2

# %%
x
# Out:
# 156

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
'harshit' in ['ishika', 'harsh gill', 'kanika']
# Out:
# False

# %%
'harshit' not in ['ishika', 'harsh gill', 'kanika']
# Out:
# True

# %%
x = 56

# %%
y = 56

# %%
x is y
# Out:
# True

# %%
x is not y
# Out:
# False

# %%
x = ['apple', 'mango', 'banana']

y = x

# %%
x is y
# Out:
# True

# %%
z = ['apple', 'mango', 'banana']

# %%
x is z
# Out:
# False

# %%
id(z)
# Out:
# 4382032584

# %%
id(x)
# Out:
# 4382031944

# %%
x = 56

# %%
y = 56

# %%
id(x)
# Out:
# 4342518360

# %%
id(y)
# Out:
# 4342518360

# %%
id(x) == id(y)
# Out:
# True
